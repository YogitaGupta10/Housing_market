# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/Melbourne_housing_FULL.csv')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-6-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# cols = df.columns
# for col in cols:
#   print(col)

#   print(df[col].unique())
#   print('------------------')

# %%
df.columns[df.eq(0).any()]
# Out:
# Index(['Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea'], dtype='object')

# %%
df['Landsize'].eq(0).sum()
# Out:
# 2437

# %%
median_landsize= df['Landsize'].median()

# %%
df['Landsize'] = df['Landsize'].fillna(median_landsize)

# %%
df['Landsize'] = df['Landsize'].replace(0, median_landsize)

# %%
df['Landsize'].eq(0).sum()
# Out:
# 0

# %%
sns.histplot(df['Price'], color='maroon', kde=True, bins=20, alpha=0.5, fill=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
df['Type'].unique()
# Out:
# array(['h', 'u', 't'], dtype=object)

# %%
plt.bar(df['Type'], df['Price'], color ='maroon',
        width = 0.4)

plt.xlabel("type of property")
plt.ylabel("Price of the property")
plt.title("Price of different property")
plt.show()

# %%
df['Price'].isnull().sum()
# Out:
# 7610

# %%
df['Price'] = df['Price'].fillna(df.groupby('Type')['Price'].transform('mean'))

# %%
df['Price'].isnull().sum()
# Out:
# 0

# %%
sns.histplot(df['Price'], color='maroon', kde=True, bins=20, alpha=0.5, fill=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
median_bathroom = df['Bathroom'].median()

# %%
df['Bathroom'] = df['Bathroom'].fillna(median_bathroom)

# %%
df['Bathroom'] = df['Bathroom'].replace(0, median_bathroom)

# %%
median_bedroom = df['Bedroom2'].median()
df['Bedroom2'] = df['Bedroom2'].fillna(median_bedroom)

# %%
df['Bedroom2'] = df['Bedroom2'].replace(0, median_bedroom)

# %%
mean_car = df['Car'].mean()
df['Car'] = df['Car'].fillna(mean_car)

# %%
df['Car'].eq(0).sum()
# Out:
# 1631

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df['BuildingArea'] = df['BuildingArea'].fillna(df['BuildingArea'].median())

# %%
df['BuildingArea']= df['BuildingArea'].replace(0, df['BuildingArea'].median())

# %%
df['BuildingArea'].eq(0).sum()
# Out:
# 0

# %%
mode= df['YearBuilt'].mode()[0]
df['YearBuilt'] = df['YearBuilt'].fillna(mode)

# %%
df['Longtitude'] = df['Longtitude'].fillna(df['Longtitude'].mean())

# %%
df['Lattitude'] = df['Lattitude'].fillna(df['Lattitude'].mean())

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         1
# Postcode         1
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      3
# Lattitude        0
# Longtitude       0
# Regionname       3
# Propertycount    3
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-39-b9c6864122be>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
columns_drop = ['Distance', 'Postcode', 'CouncilArea', 'Regionname', 'Propertycount']

# %%
df = df.dropna(subset=['Distance', 'Postcode', 'CouncilArea', 'Regionname', 'Propertycount'])

# %%
df.columns[df.eq(0).any()]
# Out:
# Index(['Distance', 'Car'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type         Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h  1.203718e+06     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1.480000e+06      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1.035000e+06      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u  6.279434e+05     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1.465000e+06     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0 2016-03-09       2.5    3067.0  ...       1.0  1.0     126.0         136.0
# 1 2016-03-12       2.5    3067.0  ...       1.0  1.0     202.0         136.0
# 2 2016-04-02       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3 2016-04-02       2.5    3067.0  ...       2.0  1.0     521.0         136.0
# 4 2017-04-03       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df['Price'].unique()
# Out:
# array([1203718.49978346, 1480000.        , 1035000.        , ...,
#        2685000.        , 1671000.        , 1605500.        ])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['Type'] = label_encoder.fit_transform(df['Type'])
df['Suburb'] = label_encoder.fit_transform(df['Suburb'])
df['Address'] = label_encoder.fit_transform(df['Address'])
df['Method'] = label_encoder.fit_transform(df['Method'])
df['SellerG'] = label_encoder.fit_transform(df['SellerG'])
df['CouncilArea'] = label_encoder.fit_transform(df['CouncilArea'])

# %%
ordinal_encoder = OrdinalEncoder()

# %%
#this will encode them into numerical value according to their ranks.
df['Regionname'] = ordinal_encoder.fit_transform(df[['Regionname']])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scale = ['Rooms', 'Price', 'Distance', 'Postcode']

# %%
df[scale] = scaler.fit_transform(df[scale])

# %%
df.head()
# Out:
#    Suburb  Address     Rooms  Type     Price  Method  SellerG       Date  \
# 0       0    29455  0.066667     0  0.100649       6      155 2016-03-09
# 1       0    32509  0.066667     0  0.125506       2       33 2016-03-12
# 2       0    15386  0.066667     0  0.085470       2       33 2016-04-02
# 3       0     9767  0.133333     2  0.048848       7      296 2016-04-02
# 4       0    25125  0.133333     0  0.124157       5       33 2017-04-03
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0  0.051975  0.068507  ...       1.0  1.0     126.0         136.0     1970.0
# 1  0.051975  0.068507  ...       1.0  1.0     202.0         136.0     1970.0
# 2  0.051975  0.068507  ...       1.0  0.0     156.0          79.0     1900.0
# 3  0.051975  0.068507  ...       2.0  1.0     521.0         136.0     1970.0
# 4  0.051975  0.068507  ...       2.0  0.0     134.0         150.0     1900.0
#
# ...

# %%
df.boxplot(column='Distance')
plt.title('distance outliers')
plt.suptitle('')
plt.show()

# %%
df.boxplot(column='Rooms')
plt.title('Room outliers')
plt.suptitle('')
plt.show()

# %%
df.boxplot(column='Price')
plt.title('Price outliers')
plt.suptitle('')
plt.show()

# %%
df.boxplot(column='Postcode')
plt.title('Postcode outliers')
plt.suptitle('')
plt.show()

# %%
import plotly.express as exp

# %%
exp.box(df['Price'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# columns_with_outliers = ['Rooms', 'Price', 'Distance']

# %%
# threshold=3

# %%
# def winsorize_outliers(data, col):
#     q75, q25 = np.percentile(data[col], [75, 25])
#     iqr = q75 - q25
#     min_val = q25 - (threshold * iqr)
#     max_val = q75 + (threshold * iqr)
#     data[col] = np.clip(data[col], min_val, max_val)
#     return data

# %%
# def remove_outliers(data, col):
#     z_scores = (data[col] - data[col].mean()) / data[col].std()
#     data = data.loc[abs(z_scores) < threshold]
#     return data

# %%
# for col in columns_with_outliers:
#     df = winsorize_outliers(df, col)
#     df = remove_outliers(df, col)

# %%
# plt.figure(figsize=(8,5))
# plt.suptitle("Rooms Distribution after handling outliers", fontsize=18)
# plt.subplot(1,2,1)
# sns.kdeplot(data = df['Rooms'])
# plt.subplot(1,2,2)
# sns.boxplot(data = df['Rooms'], palette="magma")
# plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(8,5))
# plt.suptitle("Distance Distribution after handling outliers", fontsize=18)
# plt.subplot(1,2,1)
# sns.kdeplot(data = df['Distance'])
# plt.subplot(1,2,2)
# sns.boxplot(data = df['Distance'])
# plt.tight_layout()
# plt.show()

# %%
import scipy
from scipy import stats

# %%
# df.hist(bins=20, figsize =(15,10), color= 'maroon')

# %%
# from sklearn.preprocessing import StandardScaler

# %%
# std=StandardScaler()

# %%
# df["SellerG"]=std.fit_transform(df[["SellerG"]])

# %%
# df["Price"]=std.fit_transform(df[["Price"]])

# %%
# import plotly.express as px
# fig = px.box(df, y="Price")
# fig.show()

# %%
print("outliers:", df[df["Price"]>=2.432368].count())
# Out:
# outliers: Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.shape
# Out:
# (34854, 21)

# %%
# fig = px.box(df, y="Landsize")
# fig.show()

# %%
print("outliers:\n" , df[(df['Landsize'] >= 20000)].count())
# Out:
# outliers:
#  Suburb           23
# Address          23
# Rooms            23
# Type             23
# Price            23
# Method           23
# SellerG          23
# Date             23
# Distance         23
# Postcode         23
# Bedroom2         23
# Bathroom         23
# Car              23
# Landsize         23
# BuildingArea     23
# YearBuilt        23
# CouncilArea      23
# Lattitude        23
# Longtitude       23
# Regionname       23
# Propertycount    23
# dtype: int64

# %%
df = df[df['Landsize'] <= 20000]

# %%
# fig = px.box(df, x="BuildingArea")
# fig.show()

# %%
print("outliers:\n" , df[(df['BuildingArea'] >= 1000)].count())
# Out:
# outliers:
#  Suburb           12
# Address          12
# Rooms            12
# Type             12
# Price            12
# Method           12
# SellerG          12
# Date             12
# Distance         12
# Postcode         12
# Bedroom2         12
# Bathroom         12
# Car              12
# Landsize         12
# BuildingArea     12
# YearBuilt        12
# CouncilArea      12
# Lattitude        12
# Longtitude       12
# Regionname       12
# Propertycount    12
# dtype: int64

# %%
df = df[df['BuildingArea'] <= 1000]

# %%
print("outliers:\n" , df[(df['Rooms'] >= 4)].count())
# Out:
# outliers:
#  Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.shape
# Out:
# (34819, 21)

# %%
df.dtypes
# Out:
# Suburb                    int64
# Address                   int64
# Rooms                   float64
# Type                      int64
# Price                   float64
# Method                    int64
# SellerG                   int64
# Date             datetime64[ns]
# Distance                float64
# Postcode                float64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea               int64
# Lattitude               float64
# Longtitude              float64
# Regionname              float64
# Propertycount           float64
# dtype: object

# %%
cr= df.corr()
cr_df= cr['Price'].sort_values(ascending= False)
cr_df
# Out:
# <ipython-input-87-8e03ea8d3393>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Price            1.000000
# Rooms            0.447956
# Bedroom2         0.365386
# BuildingArea     0.309617
# Bathroom         0.299860
# Car              0.169850
# Longtitude       0.158930
# Regionname       0.061620
# Postcode         0.043867
# Address          0.040003
# Landsize         0.028918
# Method          -0.009305
# SellerG         -0.045988
# Propertycount   -0.057210
# CouncilArea     -0.101998
# Suburb          -0.124429
# Distance        -0.167561
# Lattitude       -0.168454
# YearBuilt       -0.218022
# Type            -0.406443
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import explained_variance_score,mean_absolute_error,r2_score

# %%
X= df.drop(['Price', 'Date'], axis=1)
y = df.Price

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# %%
rf= RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2= rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred2)
r2_square = r2_score(y_test,y_pred2)
rms = np.sqrt(mean_squared_error(y_test, y_pred2))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.60874529692311
# Mean Squared Error: 0.0010417875351094162
# Root Mean Squared Error: 0.03227673364994383

# %%
dt= DecisionTreeRegressor()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred3= rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred3)
r2_square = r2_score(y_test,y_pred3)
rms = np.sqrt(mean_squared_error(y_test, y_pred3))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.60874529692311
# Mean Squared Error: 0.0010417875351094162
# Root Mean Squared Error: 0.03227673364994383

# %%
xgb=XGBRegressor()
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred4=xgb.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred4)
r2_square = r2_score(y_test,y_pred4)
rms = np.sqrt(mean_squared_error(y_test, y_pred4))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.6002715082638577
# Mean Squared Error: 0.0010643505543675529
# Root Mean Squared Error: 0.03262438588491058

# %%
lgb= LGBMRegressor()
lgb.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001693 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2544
# [LightGBM] [Info] Number of data points in the train set: 27855, number of used features: 19
# [LightGBM] [Info] Start training from score 0.087407
# LGBMRegressor()

# %%
y_pred5=lgb.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred5)
r2_square = r2_score(y_test,y_pred5)
rms = np.sqrt(mean_squared_error(y_test, y_pred5))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.6299426288122979
# Mean Squared Error: 0.0009853457442093498
# Root Mean Squared Error: 0.031390217332942276

# %%
gb= GradientBoostingRegressor()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred6=gb.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred6)
r2_square = r2_score(y_test,y_pred6)
rms = np.sqrt(mean_squared_error(y_test, y_pred6))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.5803414614881808
# Mean Squared Error: 0.0011174179658050777
# Root Mean Squared Error: 0.03342780228799192

# %%
hgb= HistGradientBoostingRegressor()
hgb.fit(X_train,y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
y_pred7=hgb.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred7)
r2_square = r2_score(y_test,y_pred7)
rms = np.sqrt(mean_squared_error(y_test, y_pred7))
print(f" R-squared: {r2_square}")
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rms}')
# Out:
#  R-squared: 0.6250701549941329
# Mean Squared Error: 0.0009983196010064496
# Root Mean Squared Error: 0.03159619598949294

# %% [markdown]
# when no outlier/ min max was done:
#
# best R2 score= 63.5%
#
# when min max was done:
#
# best R2 score= 63.5%(over the same model)
#
# when both min max is done and outliers are removed:
#
# best R2 score: 62.9% (over the same model)
